# %% [markdown]
# # Projet - Modélisation et simulation d'un système de vélos partagés - SPEISMANN & POURNY

# %%
import numpy as np
import random as rd
from math import sqrt

# %% [markdown]
# ## Calibration des paramètres

# %% [markdown]
# ### Données

# %%
# Matrice du temps de trajet moyen entre les stations:
Tau = np.array([[0, 3, 5, 7, 7],
                [2, 0, 2, 5, 5],
                [4, 2, 0, 3, 3],
                [8, 6, 4, 0, 2],
                [7, 7, 5, 2, 0]])

# Matrice de routage (Proba de passage d'un vélo de i vers j):
P = np.array([[0, 0.22, 0.32, 0.20, 0.26],
              [0.17, 0, 0.34, 0.21, 0.28],
              [0.19, 0.26, 0, 0.24, 0.31],
              [0.17, 0.22, 0.33, 0, 0.28],
              [0.18, 0.24, 0.35, 0.23, 0]]) 

# Intensité de départ par heure par station: 
Lambda = np.array([2.8, 3.7, 5.5, 3.5, 4.6])

# Nombre de vélos initial dans chaque station:
V0 = np.array([20, 15, 17, 13, 18])

# %% [markdown]
# ### Définir les Paramètres

# %% [markdown]
# Seul les $\mu$ se calculent à partir des données.
#
# Les $\lambda$ et les $p_{i,j}$ sont automatiquement déductible des données

# %%
Mu = [[None if i == j else 1 / Tau[i, j] for j in range(5)] for i in range(5)]
# Out:
# [[None, 0.3333333333333333, 0.2, 0.14285714285714285, 0.14285714285714285],
#  [0.5, None, 0.5, 0.2, 0.2],
#  [0.25, 0.5, None, 0.3333333333333333, 0.3333333333333333],
#  [0.125, 0.16666666666666666, 0.25, None, 0.5],
#  [0.14285714285714285, 0.14285714285714285, 0.2, 0.5, None]]

# %% [markdown]
# ## Simulation

# %% [markdown]
# ### Définir l'état initial:

# %%
# Etat inital:
S0 = np.concatenate([V0, np.zeros(5 * 4, dtype=int)])  # On suppose que le système commence sans vélo en trajet.

# %% [markdown]
# Tableau d'aide pour récupérer les indices des $S_{T_{i,j}}

# %%
index_S_T = [[None, 5, 6, 7, 8],
        [9, None, 10, 11, 12],
        [13, 14, None, 15, 16],
        [17, 18, 19, None, 20],
        [21, 22, 23, 24, None]]

# %% [markdown]
# ### Définir une simulation

# %%
def simulation(S = S0, T = 150):
    t = 0
    temps = [t]
    historique = [S.copy()]
    while t < T:
        taux = [[[None if i == j else Lambda[i] * P[i][j] * (S[i]>0) for j in range(5)] for i in range(5)], 
                [[None if i == j else Mu[i][j] * S[index_S_T[i][j]] for j in range(5)] for i in range(5)]]
        taux_sortie_etat = sum([taux[0][i][j] + taux[1][i][j] for i in range(5) for j in range(5) if i != j])

        t+=np.random.exponential(1/taux_sortie_etat) # Le taux est bien la somme, spécificité de la fonction.
        temps.append(t)
        # Evenement qui a lieu:
        indices = [(k, i, j) for k in range(2) for i in range(5) for j in range(5) if i != j]
        poids = np.array([taux[k][i][j] for k, i, j in indices], dtype=float)
        prob = poids / taux_sortie_etat
        k_evt, i_evt, j_evt = indices[np.random.choice(len(indices), p=prob)]

        # Départ d'un vélo de i vers j:
        if k_evt == 0:
            S[i_evt] -= 1
            S[index_S_T[i_evt][j_evt]] += 1
            
        # Arrivé d'un vélo de i vers j:
        elif k_evt == 1:
            S[index_S_T[i_evt][j_evt]] -= 1
            S[j_evt] += 1
            
        historique.append(S.copy())
    return S, historique, temps

# %% [markdown]
# ### Estimation d'une station vide à l'horizon

# %%
M = 200
res = 0
historique = [S0]
for i in range(M):
    print("Simulation numéro: ", i+1)
    S, _, _ = simulation()
    if 0 in S[0:5]:
        res += 1
    
p = res/M
print(p)
# Out:
# Simulation numéro:  1
# Simulation numéro:  2
# Simulation numéro:  3
# Simulation numéro:  4
# Simulation numéro:  5
# Simulation numéro:  6
# Simulation numéro:  7
# Simulation numéro:  8
# Simulation numéro:  9
# Simulation numéro:  10
# Simulation numéro:  11
# Simulation numéro:  12
# Simulation numéro:  13
# Simulation numéro:  14
# Simulation numéro:  15
# Simulation numéro:  16
# Simulation numéro:  17
# Simulation numéro:  18
# Simulation numéro:  19
# Simulation numéro:  20
# Simulation numéro:  21
# Simulation numéro:  22
# Simulation numéro:  23
# Simulation numéro:  24
# Simulation numéro:  25
# Simulation numéro:  26
# Simulation numéro:  27
# Simulation numéro:  28
# Simulation numéro:  29
# Simulation numéro:  30
# Simulation numéro:  31
# Simulation numéro:  32
# Simulation numéro:  33
# Simulation numéro:  34
# Simulation numéro:  35
# Simulation numéro:  36
# Simulation numéro:  37
# Simulation numéro:  38
# Simulation numéro:  39
# Simulation numéro:  40
# Simulation numéro:  41
# Simulation numéro:  42
# Simulation numéro:  43
# Simulation numéro:  44
# Simulation numéro:  45
# Simulation numéro:  46
# Simulation numéro:  47
# Simulation numéro:  48
# Simulation numéro:  49
# Simulation numéro:  50
# Simulation numéro:  51
# Simulation numéro:  52
# Simulation numéro:  53
# Simulation numéro:  54
# Simulation numéro:  55
# Simulation numéro:  56
# Simulation numéro:  57
# Simulation numéro:  58
# Simulation numéro:  59
# Simulation numéro:  60
# Simulation numéro:  61
# Simulation numéro:  62
# Simulation numéro:  63
# Simulation numéro:  64
# Simulation numéro:  65
# Simulation numéro:  66
# Simulation numéro:  67
# Simulation numéro:  68
# Simulation numéro:  69
# Simulation numéro:  70
# Simulation numéro:  71
# Simulation numéro:  72
# Simulation numéro:  73
# Simulation numéro:  74
# Simulation numéro:  75
# Simulation numéro:  76
# Simulation numéro:  77
# Simulation numéro:  78
# Simulation numéro:  79
# Simulation numéro:  80
# Simulation numéro:  81
# Simulation numéro:  82
# Simulation numéro:  83
# Simulation numéro:  84
# Simulation numéro:  85
# Simulation numéro:  86
# Simulation numéro:  87
# Simulation numéro:  88
# Simulation numéro:  89
# Simulation numéro:  90
# Simulation numéro:  91
# Simulation numéro:  92
# Simulation numéro:  93
# Simulation numéro:  94
# Simulation numéro:  95
# Simulation numéro:  96
# Simulation numéro:  97
# Simulation numéro:  98
# Simulation numéro:  99
# Simulation numéro:  100
# Simulation numéro:  101
# Simulation numéro:  102
# Simulation numéro:  103
# Simulation numéro:  104
# Simulation numéro:  105
# Simulation numéro:  106
# Simulation numéro:  107
# Simulation numéro:  108
# Simulation numéro:  109
# Simulation numéro:  110
# Simulation numéro:  111
# Simulation numéro:  112
# Simulation numéro:  113
# Simulation numéro:  114
# Simulation numéro:  115
# Simulation numéro:  116
# Simulation numéro:  117
# Simulation numéro:  118
# Simulation numéro:  119
# Simulation numéro:  120
# Simulation numéro:  121
# Simulation numéro:  122
# Simulation numéro:  123
# Simulation numéro:  124
# Simulation numéro:  125
# Simulation numéro:  126
# Simulation numéro:  127
# Simulation numéro:  128
# Simulation numéro:  129
# Simulation numéro:  130
# Simulation numéro:  131
# Simulation numéro:  132
# Simulation numéro:  133
# Simulation numéro:  134
# Simulation numéro:  135
# Simulation numéro:  136
# Simulation numéro:  137
# Simulation numéro:  138
# Simulation numéro:  139
# Simulation numéro:  140
# Simulation numéro:  141
# Simulation numéro:  142
# Simulation numéro:  143
# Simulation numéro:  144
# Simulation numéro:  145
# Simulation numéro:  146
# Simulation numéro:  147
# Simulation numéro:  148
# Simulation numéro:  149
# Simulation numéro:  150
# Simulation numéro:  151
# Simulation numéro:  152
# Simulation numéro:  153
# Simulation numéro:  154
# Simulation numéro:  155
# Simulation numéro:  156
# Simulation numéro:  157
# Simulation numéro:  158
# Simulation numéro:  159
# Simulation numéro:  160
# Simulation numéro:  161
# Simulation numéro:  162
# Simulation numéro:  163
# Simulation numéro:  164
# Simulation numéro:  165
# Simulation numéro:  166
# Simulation numéro:  167
# Simulation numéro:  168
# Simulation numéro:  169
# Simulation numéro:  170
# Simulation numéro:  171
# Simulation numéro:  172
# Simulation numéro:  173
# Simulation numéro:  174
# Simulation numéro:  175
# Simulation numéro:  176
# Simulation numéro:  177
# Simulation numéro:  178
# Simulation numéro:  179
# Simulation numéro:  180
# Simulation numéro:  181
# Simulation numéro:  182
# Simulation numéro:  183
# Simulation numéro:  184
# Simulation numéro:  185
# Simulation numéro:  186
# Simulation numéro:  187
# Simulation numéro:  188
# Simulation numéro:  189
# Simulation numéro:  190
# Simulation numéro:  191
# Simulation numéro:  192
# Simulation numéro:  193
# Simulation numéro:  194
# Simulation numéro:  195
# Simulation numéro:  196
# Simulation numéro:  197
# Simulation numéro:  198
# Simulation numéro:  199
# Simulation numéro:  200
# 0.735

# %% [markdown]
# #### Calcul de l'intervalle de confiance (à 95%)

# %%
incertitude = 1.96 * sqrt(p * (1-p) / M)
print([p - incertitude, p + incertitude])
# Out:
# [0.6738343380645644, 0.7961656619354356]

# %% [markdown]
# ### Estimation du temps où au moins une station est vide sur une simulation

# %%
_, historique, temps = simulation()
N = len(temps)
res = 0
for i in range(N-1):
    if 0 in historique[i][0:5]:
        res += temps[i+1] - temps[i]

print(res/temps[-1])
# Out:
# 0.747518405386027
